# %%
pip install pyodbc
# Out:
# Requirement already satisfied: pyodbc in c:\users\samsung\appdata\local\programs\python\python313\lib\site-packages (5.3.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyodbc

connection_data = (
    "Driver={SQL Server};"
    "Server=LAPTOP-SRP0M4NC;"
    "Database=PythonSQL;"
)

connection = pyodbc.connect(connection_data)
print("Connection successful!")
# Out:
# Connection successful!

# %%
cursor = connection.cursor()

sale_id = 6
sale_date = "2023-06-17"
customer = "Diego"
product = "Tablet"
price = 1200
quantity = 1

command = f"""INSERT INTO Sales (sale_id, sale_date, customer, product, price, quantity)
VALUES ({sale_id}, '{sale_date}', '{customer}', '{product}', {price}, {quantity})"""

cursor.execute(command)
cursor.commit()

print("Data successfully inserted!")
# Out:
# Data successfully inserted!
